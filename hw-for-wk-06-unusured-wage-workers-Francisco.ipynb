# %%
#import pandas
import pandas as pd

# %%
#import data and create data frame
df = pd.read_csv("data/unusured-wage-workers.csv", skiprows=6)
df
# Out:
#      Recoded detailed Hispanic origin      Total  Total Selected Geographies  \
# 0                            -> Total  194477570                    41397800
# 1         Not Spanish/Hispanic/Latino  156345007                    29046882
# 2                             Mexican   23060400                     8049626
# 3                        Puerto Rican    3375309                     1121209
# 4                               Cuban    2014133                      477347
# 5                           Dominican     975256                      357600
# 6                         Costa Rican     111442                       20201
# 7                          Guatemalan    1117944                      397224
# 8                            Honduran     543100                      160445
# 9                          Nicaraguan     350783                       88533
# 10                         Panamanian     122698                       20834
# ...
